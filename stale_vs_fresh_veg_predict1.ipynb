# %%
filepath = "/content/drive/MyDrive/sales and fresh veg/archive.zip"

# %%
from zipfile import ZipFile

with ZipFile(filepath) as f:
  f.extractall("./fruit")
  print("Data extracted")
# Out:
# Data extracted

# %%
import tensorflow as tf
from tensorflow.keras import layers
from PIL import Image
import numpy as np

# %%
model=tf.keras.models.load_model("/content/drive/MyDrive/stales and fresh vegetables/fruits.h5")
classes =[
    "fresh_apple",
    "fresh_banana",
    "fresh_bitter_gourd",
    "fresh_capsicum",
    "fresh_orange",
    "fresh_tomato",
    "stale_apple",
    "stale_banana",
    "stale_bitter_gourd",
    "stale_capsicum",
    "stale_orange",
    "stale_tomato"
]
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 18)        1368
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 18)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 18)        2934
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 18)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 36)        5868
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 36)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 36)          11700
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 36)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 100)               57700
#
#  dense_1 (Dense)             (None, 12)                1212
#
#  softmax (Softmax)           (None, 12)                0
#
# ...
# Total params: 80,782
# Trainable params: 80,782
# ...

# %%
image = Image.open("/content/fruit/fresh_banana/Screen Shot 2018-06-12 at 10.02.36 PM.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=580x384 at 0x7F7A83D567F0>

# %%
image=image.resize((64,64))
image
# Out:
# <PIL.Image.Image image mode=RGBA size=64x64 at 0x7F7A700F3670>

# %%
def Pred(fruit):
  image = Image.open(fruit)
  image = image.resize((64,64))
  test = tf.reshape(tf.constant(np.array(image)/255),(-1,64,64,3))
  preds = model.predict(test, verbose=False)[0]*100
  preds = tf.math.round(preds)
  confidence = tf.reduce_max(preds)
  index = int(tf.where(preds == confidence)[0][0])
  pred = classes[index]
  print (pred.title(),int(confidence),"%")

# %%
im = Image.open("/content/fruit/fresh_orange/Screen Shot 2018-06-12 at 11.52.40 PM.png")
rgb_im = im.convert('RGB')
rgb_im.save('/content/fruit/fresh_orange/orangejpg.jpg')
rgb_im
# Out:
# <PIL.Image.Image image mode=RGB size=352x306 at 0x7F7A049350A0>

# %%
Pred("/content/fruit/fresh_orange/orangejpg.jpg")
# Out:
# Fresh_Orange 100 %

# %%
im = Image.open("/content/fruit/stale_tomato/Copy of IMG_20200727_223202.jpg_0_5856.jpg")
im.resize((64,64))
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7A049359D0>

# %%
Pred("/content/fruit/stale_tomato/Copy of IMG_20200727_223202.jpg_0_5856.jpg")
# Out:
# Stale_Tomato 100 %

# %%
im = Image.open("/content/fruit/fresh_capsicum/Day1A.jpg_0_4148.jpg")
im.resize((64,64))
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7A91F1BEB0>

# %%
Pred("/content/fruit/fresh_capsicum/Day1A.jpg_0_4148.jpg")
# Out:
# Fresh_Capsicum 100 %

# %%
im=Image.open("/content/fruit/stale_bitter_gourd/IMG_20200824_182208.jpg_0_9114.jpg")
im.resize((64,64))
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7A70102B50>

# %%
Pred("/content/fruit/stale_bitter_gourd/IMG_20200824_182208.jpg_0_9114.jpg")
# Out:
# Stale_Bitter_Gourd 100 %
